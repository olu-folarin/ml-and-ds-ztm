# %% [markdown]
# # Intro to Matplotlib

# %%
#all plots should appear in dis notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# creating a blank plot
plt.plot()
# Out:
# []

# %%
#to het rid of the square brackets right above the plot, end the code with a semi-colon ;
plt.plot();

# %%
plt.plot([1,2,3,4,5]);

# %%
#this style of plotting is referred to as Stateless
a = [1,2,3,4,5]
b = [10,11,12,13,14]
plt.plot(a,b);

# %% [markdown]
# ### three plotting methods

# %%
#1
fig = plt.figure() #creates a figure
ax = fig.add_subplot() #adds axes
plt.show()

# %%
#2
fig = plt.figure()
ax = fig.add_axes([1,1,1,1]) #this must be ones
ax.plot(a,b) #add some data
plt.show()

# %%
#3 (recommended method)
# a figure is like a warehouse where multiple subplots could be housed
fig, ax = plt.subplots() #creates a figure and a set of subplots(multiple plots) default nrows and ncols is 1
ax.plot(a,b); #plots d data in a and b to the figure/plot
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## matplotlib example workflow

# %%
#1. import matplotlib and have it ready for plotting in jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt

#2. prepare data
c = [1,2,3,4,5]
d = [20,21,22,23,24]

#3. setup plot
    #figsize spreads the data across 9 floated numbers on each axis
fig, ax = plt.subplots(figsize=(10,10))

#4. plot data
ax.plot(c,d)

#5. customize plot
ax.set(title="Introductory Plot", xlabel="x-axis",
      ylabel="y-axis")

#6. save and show (save the whole figure)
fig.savefig("images/sample-plot1.png")

# %% [markdown]
# ### making figures with NumPy arrays
#
# The most common plots are:
#
# * line plot
# * scatter plot
# * histogram
# * bar plot
# * subplots

# %%
# create some data with NumPy linspace
#linspace(): returns evenly spaced numbers over a specified interval
x = np.linspace(2,14,100)
x
# Out:
# array([ 2.        ,  2.12121212,  2.24242424,  2.36363636,  2.48484848,
#         2.60606061,  2.72727273,  2.84848485,  2.96969697,  3.09090909,
#         3.21212121,  3.33333333,  3.45454545,  3.57575758,  3.6969697 ,
#         3.81818182,  3.93939394,  4.06060606,  4.18181818,  4.3030303 ,
#         4.42424242,  4.54545455,  4.66666667,  4.78787879,  4.90909091,
#         5.03030303,  5.15151515,  5.27272727,  5.39393939,  5.51515152,
#         5.63636364,  5.75757576,  5.87878788,  6.        ,  6.12121212,
#         6.24242424,  6.36363636,  6.48484848,  6.60606061,  6.72727273,
#         6.84848485,  6.96969697,  7.09090909,  7.21212121,  7.33333333,
#         7.45454545,  7.57575758,  7.6969697 ,  7.81818182,  7.93939394,
#         8.06060606,  8.18181818,  8.3030303 ,  8.42424242,  8.54545455,
#         8.66666667,  8.78787879,  8.90909091,  9.03030303,  9.15151515,
#         9.27272727,  9.39393939,  9.51515152,  9.63636364,  9.75757576,
# ...

# %%
#plot the data and create a line plot by raising x to the power of 2
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
#create a scatter plot using the same data
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
#a wave scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
#make a plot from a dictionary and create a bar plot
food_stuff = {
    'yam': 1150,
    'pepper': 1000,
    'jameson': 10000,
    'transport': 800,
    'fish': 2200,
    'pomo': 1950,
    'bag': 100,
    'pepper grinding': 100,
    'okra': 200
}

fig, ax = plt.subplots()
ax.bar(food_stuff.keys(), food_stuff.values(), color='teal');
ax.set(title="Items I Bought at the Market",
      xlabel="Items", ylabel="Prices (#)");

# %%
# create a dictionary
friends = {
    'IK': 32,
    'Tope': 31,
    'Kola': 32,
    'Damola': 29
}

fig, ax = plt.subplots()
ax.bar(friends.keys(), friends.values(), color='red')
ax.set(title='My Friends', xlabel='Names', ylabel='Ages')
# Out:
# [Text(0.5, 1.0, 'My Friends'), Text(0.5, 0, 'Names'), Text(0, 0.5, 'Ages')]

# %%
fig, ax = plt.subplots()
ax.barh(list(friends.keys()), list(friends.values()), color="black")
# Out:
# <BarContainer object of 4 artists>

# %%
#  plotting a histogram
fig, ax = plt.subplots()
ax.hist(friends);

# %%
# creating a numpy arr
rando = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(rando);

# %% [markdown]
# ### Subplots Alternatives

# %%
# option 1
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(7,5))

# plot to each axis
ax1.plot(rando, rando/2);
ax1.set(title='A Simple Plot', xlabel="Keys", ylabel='Values')
ax2.scatter(np.random.random(7), np.random.random(7));
ax2.set(title="A Scatter Plot of Random Numbers", xlabel='Labels', ylabel="Values")
ax3.bar(friends.keys(), friends.values());
ax3.set(title='A Bar Chart of Some Friends', xlabel='Friends', ylabel='Ages')
ax4.hist(rando);
ax4.set(title="A Histogram showing Random Numbers", xlabel='Keys', ylabel="Values")
# Out:
# [Text(0.5, 1.0, 'A Histogram showing Random Numbers'),
#  Text(0.5, 0, 'Keys'),
#  Text(0, 0.5, 'Values')]

# %%
# option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(7,5))

# plot to each index
ax[0,0].plot(rando, rando/2); #row1,col1
ax[0,1].scatter(np.random.random(8), np.random.random(8));
ax[1,0].bar(friends.keys(), friends.values(), color='green');
ax[1,1].hist(np.random.randn(1100));

# %% [markdown]
# ## Plotting from Pandas DataFrames

# %%
#1. Make a dataframe
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#something from pandas dataframe visulaization
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot();

# %% [markdown]
# ### plotting with real data

# %%
#formatting the price column in car_sales.csv
    #replace the indicated chars with an empty string
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '')
car_sales
# Out:
# C:\Users\this\AppData\Local\Temp/ipykernel_15808/2814247969.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales['Price'][0])
# Out:
# str

# %%
# remove last two zeros
car_sales['Price'] = car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# add dates for the sales
car_sales['Sale Date'] = pd.date_range('1/1/2020', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
#add a total column with cumsum() by first changing the Price column to int
car_sales['Total Sales'] = car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales ($)  \
# 0  Toyota  White         150043      4   4000 2020-01-01             4000
# 1   Honda    Red          87899      4   5000 2020-01-02             9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03            16000
# 3     BMW  Black          11179      5  22000 2020-01-04            38000
# 4  Nissan  White         213095      4   3500 2020-01-05            41500
# 5  Toyota  Green          99213      4   4500 2020-01-06            46000
# 6   Honda   Blue          45698      4   7500 2020-01-07            53500
# 7   Honda   Blue          54738      4   7000 2020-01-08            60500
# 8  Toyota  White          60000      4   6250 2020-01-09            66750
# 9  Nissan  White          31600      4   9700 2020-01-10            76450
#
#    Total Sales
# 0         4000
# 1         9000
# 2        16000
# 3        38000
# 4        41500
# 5        46000
# 6        53500
# 7        60500
# ...

# %%
#plot total sales over sales date
car_sales.plot(x='Sale Date', y='Total Sales', color='purple');
# car_sales.set(title='Sales Tracker', xlabel='Sales Value', ylabel='Sales Dates')

# %%
#scatter plot. However, you may want to reassign the price as int
car_sales['Price'] = car_sales['Price'].astype(int)
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
#multiple plots in a figure
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(13,12))
# give the subplots padding
plt.tight_layout(pad=5)

#plotting the subplots
car_sales['Price'] = car_sales['Price'].astype(int)
ax1.plot(car_sales['Sale Date'], car_sales['Price']);
ax1.set(title="Car Prices and Dates", xlabel='Dates', ylabel='Prices');

ax2.bar(car_sales['Make'], car_sales['Total Sales'], color='grey');
ax2.set(title="Car Brands and Total Sales", xlabel='Brand', ylabel='Total Sales');

ax3.hist(car_sales['Total Sales'], color='purple');
ax3.set(title="Total Sales of Respective Brands", xlabel='Total Sales', ylabel='Units');

ax4.scatter(car_sales['Sale Date'], car_sales['Total Sales'], color='red');
ax4.set(title="Total Sales with Dates", xlabel='Dates', ylabel='Total Sales');

# %%
# creating a random pandas dataframe to be plotted on a graph
f = np.random.rand(10,5)
df = pd.DataFrame(f, columns=['i', 'ii', 'iii', 'iv', 'v'])
df
# Out:
#           i        ii       iii        iv         v
# 0  0.554920  0.694174  0.423822  0.357641  0.035708
# 1  0.749666  0.219252  0.968002  0.559896  0.253620
# 2  0.300606  0.703731  0.496773  0.075121  0.023835
# 3  0.604075  0.441303  0.769689  0.746468  0.707633
# 4  0.376772  0.595850  0.474995  0.141714  0.568572
# 5  0.630653  0.932471  0.426487  0.748809  0.417080
# 6  0.516119  0.954749  0.997326  0.530683  0.730670
# 7  0.298656  0.650567  0.849251  0.723379  0.555149
# 8  0.817644  0.323312  0.401455  0.273597  0.230885
# 9  0.537846  0.080809  0.503274  0.302832  0.040174

# %%
df.plot(kind='hist');

# %%
df.plot.bar();

# %%
df.plot(kind='barh');
# Out:
# <AxesSubplot:>

# %%
#creating visuals for the car_sales df
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales ($)  \
# 0  Toyota  White         150043      4   4000 2020-01-01             4000
# 1   Honda    Red          87899      4   5000 2020-01-02             9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03            16000
# 3     BMW  Black          11179      5  22000 2020-01-04            38000
# 4  Nissan  White         213095      4   3500 2020-01-05            41500
# 5  Toyota  Green          99213      4   4500 2020-01-06            46000
# 6   Honda   Blue          45698      4   7500 2020-01-07            53500
# 7   Honda   Blue          54738      4   7000 2020-01-08            60500
# 8  Toyota  White          60000      4   6250 2020-01-09            66750
# 9  Nissan  White          31600      4   9700 2020-01-10            76450
#
#    Total Sales
# 0         4000
# 1         9000
# 2        16000
# 3        38000
# 4        41500
# 5        46000
# 6        53500
# 7        60500
# ...

# %%
car_sales['Price'] = car_sales['Price'].astype(int)
car_sales.plot(kind='bar');

# %%
plt.pie(car_sales['Price'], labels=car_sales['Make']);

# %%
car_sales.plot(x='Make', y='Total Sales', kind='barh');

# %%
#Trying evrything on another dataset
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
#create a histogram for the age
heart_disease['age'].plot.hist(bins=10);

# %%
# I have plotted so far using the Stateless Method(pyplot)
# set subplots=True to have stacked plots
heart_disease.plot(kind='hist', figsize=(10,30), subplots=True);

# %% [markdown]
# ## When to Use pyplot or OO method?
#
# * Use the pyplot method when trying to make a quick visualization
#
# * When plotting something more advanced, use the OO method

# %% [markdown]
# ### Using the OO method

# %%
# patients over 50
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over_fifty = heart_disease[heart_disease['age'] > 50]
over_fifty
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
#plot the dataframe: pyplot method
    #c is short for color
over_fifty.plot(kind='scatter',
               x='age',
               y='chol',
               c='target');

# %%
#OO method mixed with stateless/pyplot
fig, ax = plt.subplots(figsize=(10,6))
over_fifty.plot(kind='scatter',
               x='age',
               y='chol',
               c='target',
               ax=ax);

#set_xlim([start-int, end-int]): sets the limits of the z-axis
ax.set_xlim([45,100]);

# %%
#OO method unmixed
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_fifty['age'],
               y=over_fifty['chol'],
               c=over_fifty['target']);

# customise the plot
ax.set(title='Heart Disease: A Function of Age and Cholesterol Levels',
           xlabel='Age',
           ylabel='Cholesterol');

#add a legend
ax.legend(*scatter.legend_elements(), title='Target');

#add a horizontal line across the plot
ax.axhline(over_fifty['chol'].mean(),
          linestyle='--');

# %%
#subplot of age, chol and thalach
fig, (ax1, ax2) = plt.subplots(figsize=(10,12),
                              nrows=2,
                              ncols=1);
#1.
# add data to both subplots
scatter = ax1.scatter(x=over_fifty['age'],
                     y=over_fifty['chol'],
                     c=over_fifty['target']);
#customize ax1
ax1.set(title='Heart Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol');
#add a legend to ax1
ax1.legend(*scatter.legend_elements(), title='Target');
#add a mean line
ax1.axhline(y=over_fifty['chol'].mean(),
           linestyle='--');

#2.
scatter2 = ax2.scatter(x=over_fifty['age'],
                      y=over_fifty['thalach'],
                      c=over_fifty['target'])
#label ax2
ax2.set(title='Heart Disease and Maximum Heart Rate Achieved',
       xlabel='Age', ylabel='Maximum Heart Rate');
#add a legend
ax2.legend(*scatter.legend_elements(), title='Target');
#add a mean line
ax2.axhline(y=over_fifty['thalach'].mean(),
           linestyle='-.');

#add a title to the figure
fig.suptitle('Heart Disease Analysis');

# %% [markdown]
# ### styling matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#change the default style of the car_sales dataset
plt.style.use('seaborn-darkgrid')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn-dark')

# %%
car_sales['Price'].plot();

# %%
#changing the style within a style
plt.style.use('seaborn-poster')
#OO method unmixed
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_fifty['age'],
               y=over_fifty['chol'],
               c=over_fifty['target'],
                    cmap='winter');

# customise the plot
ax.set(title='Heart Disease: A Function of Age and Cholesterol Levels',
           xlabel='Age',
           ylabel='Cholesterol');

#add a legend
ax.legend(*scatter.legend_elements(), title='Target');

#add a horizontal line across the plot
ax.axhline(over_fifty['chol'].mean(),
          linestyle='--');

# %%
# customizing the x and y limitations
#subplot of age, chol and thalach
fig, (ax1, ax2) = plt.subplots(figsize=(10,12),
                              nrows=2,
                              ncols=1,
                              sharex=True);
#1.
# add data to both subplots
scatter = ax1.scatter(x=over_fifty['age'],
                     y=over_fifty['chol'],
                     c=over_fifty['target'],
                     cmap='summer');
#customize ax1
ax1.set(title='Heart Disease and Cholesterol Levels',
       ylabel='Cholesterol');
#add a legend to ax1
ax1.legend(*scatter.legend_elements(), title='Target');
#add a mean line
ax1.axhline(y=over_fifty['chol'].mean(),
           linestyle='--');
# change the x axis limits
ax1.set_ylim([100,600]);

#2.
scatter2 = ax2.scatter(x=over_fifty['age'],
                      y=over_fifty['thalach'],
                      c=over_fifty['target'],
                      cmap='summer')
#label ax2
ax2.set(title='Heart Disease and Maximum Heart Rate Achieved',
       xlabel='Age', ylabel='Maximum Heart Rate');
#add a legend
ax2.legend(*scatter.legend_elements(), title='Target');
#add a mean line
ax2.axhline(y=over_fifty['thalach'].mean(),
           linestyle='-.');
#set x and y axis limits
ax2.set_xlim([50,80]);
ax2.set_ylim([60,200]);

#add a title to the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# ###Two ways to save a matplotlib file:
#
# *
